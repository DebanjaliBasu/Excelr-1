# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression

# %%
# import Toyota Corolla  train data
tyta = pd.read_csv('/Users/halders/Documents/Excelr/dataset/toyota-corolla/train.csv',index_col=0)
tyta.rename({'Age_08_04':'Age'}, axis='columns',inplace = True)

# %%
tyta.head()
# Out:
#         Id                                              Model  Price  Age  \
# 140    142  TOYOTA Corolla 1.4 16V VVT I 5DR TERRA COMFORT...  16450   20
# 1373  1380  TOYOTA Corolla 1.6 16V LIFTB LINEA TERRA 4/5-D...   7950   75
# 764    768  TOYOTA Corolla 1.3 16V LIFTB LINEA TERRA AUT3 ...  10950   59
# 898    902  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8950   65
# 547    550   TOYOTA Corolla 1.4 16V VVT I HATCHB TERRA 2/3...   9950   55
#
#       Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ... Central_Lock  \
# 140           1      2003  22588    Petrol   97          1  ...            1
# 1373          6      1998  57144    Petrol  110          1  ...            0
# 764          10      1999  79660    Petrol   86          0  ...            0
# 898           4      1999  60000    Petrol   86          1  ...            0
# 547           2      2000  44537    Petrol   97          0  ...            0
#
# ...

# %%
Y = tyta['Price']
tyta.drop(labels =['Price'], axis = 1, inplace= True)
X= tyta

# %%
Y
# Out:
# 140     16450
# 1373     7950
# 764     10950
# 898      8950
# 547      9950
#         ...
# 748      8950
# 1355     6750
# 1276     7400
# 519     11450
# 1324     8500
# Name: Price, Length: 1292, dtype: int64

# %%
X
# Out:
#         Id                                              Model  Age_08_04  \
# 140    142  TOYOTA Corolla 1.4 16V VVT I 5DR TERRA COMFORT...         20
# 1373  1380  TOYOTA Corolla 1.6 16V LIFTB LINEA TERRA 4/5-D...         75
# 764    768  TOYOTA Corolla 1.3 16V LIFTB LINEA TERRA AUT3 ...         59
# 898    902  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...         65
# 547    550   TOYOTA Corolla 1.4 16V VVT I HATCHB TERRA 2/3...         55
# ...    ...                                                ...        ...
# 748    752  TOYOTA Corolla 1.6 16V SEDAN LINEA LUNA 4/5-Doors         61
# 1355  1362  TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-...         69
# 1276  1283          TOYOTA Corolla 1.6 16V HATCHB S 2/3-Doors         75
# 519    522   TOYOTA Corolla 1.6 16V VVT I LIFTB SOL 4/5-Doors         50
# 1324  1331                     TOYOTA Corolla 1.6HB 2/3-Doors         74
#
#       Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color   Color  ...  \
# ...
